# %%
import pandas as pd
import matplotlib.pyplot as plt
from keras.datasets import boston_housing

# %%
from sklearn.linear_model import Ridge, Lasso
from sklearn.metrics import mean_squared_error

# %%
(x_train,y_train),(x_test,y_test) =boston_housing.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 [==============================] - 0s 0us/step

# %%
x_train.shape
# Out:
# (404, 13)

# %%
clf=Ridge()

# %%
clf.fit(x_train,y_train)
# Out:
# Ridge()

# %%
y_pred=clf.predict(x_test)
y_pred
# Out:
# array([ 9.39856575, 20.50624944, 21.57130432, 33.36540233, 25.61028236,
#        20.99263222, 28.71995631, 24.87229821, 19.88375387, 22.28300617,
#        19.90485025, 18.26792666, 16.40957978, 35.53016206, 18.85902273,
#        19.50272481, 24.27551021, 20.87535722, 19.50714827, 24.69470307,
#        11.52798774, 16.33455311, 22.42878093, 12.66562797, 21.28416244,
#        23.13588726, 32.915096  , 25.17457714, 13.13132004, 20.51717897,
#        23.16771266, 18.17197362, 35.87693962, 23.141157  , 18.60220629,
#         6.00254147, 15.60180328, 22.33507389, 15.3535816 , 27.61263476,
#        22.4649764 , 28.21092786, 18.15490617, 35.01620664, 31.02216739,
#        24.61276072, 31.10364938, 18.15183519, 23.24857071, 24.09132879,
#        31.18942752, 17.82052871, 10.56289033, 13.84047016, 33.91372541,
#        27.34549734, 18.20645506, 40.25034402, 37.26382254, 24.34647993,
#        25.58241293, 20.8080617 , 19.44387436, 21.65384862, 24.7917025 ,
#        23.57930203, 17.7439233 , 26.53004086,  2.73621002, 12.06188366,
#        25.07095781, 24.28437818, 22.58634007,  7.42686055, 28.20683204,
#        20.83255722, 20.14923035, 24.74508011, 33.5627065 ,  6.97044992,
#        24.24465434, 37.33175609, 15.83213109, 18.7616193 , 20.52383071,
#        18.50562761, 22.03933497, 25.38739339, 23.89350238, 28.10059882,
#        16.93305611, 16.63168974, 26.32602667, 28.86476551, 34.69708167,
#        21.75286113, 36.70525032, 39.07650911, 24.64909594, 40.80625455,
#        33.97629377, 24.64129314])

# %%
df_y_test=pd.DataFrame(y_test,columns=["y_test"])
df_y_pred=pd.DataFrame(y_pred,columns=["y_pred"])
pd.concat([df_y_test,df_y_pred],1)
# Out:
# <ipython-input-28-97243da912a1>:3: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   pd.concat([df_y_test,df_y_pred],1)
#      y_test     y_pred
# 0       7.2   9.398566
# 1      18.8  20.506249
# 2      19.0  21.571304
# 3      27.0  33.365402
# 4      22.2  25.610282
# ..      ...        ...
# 97     21.9  39.076509
# 98     24.1  24.649096
# 99     50.0  40.806255
# 100    26.7  33.976294
# 101    25.0  24.641293
#
# [102 rows x 2 columns]

# %%
plt.plot(y_test)
plt.plot(y_pred)
plt.xlabel("Caso")
plt.ylabel("Precio")
plt.legend(["Test","Predicciones"])

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 22.548158689769743

# %% [markdown]
# Lasso

# %%
clf=Lasso()
clf.fit(x_train,y_train)
y_pred=clf.predict(x_test)

# %%
df_y_test=pd.DataFrame(y_test,columns=["y_test"])
df_y_pred=pd.DataFrame(y_pred,columns=["y_pred"])
pd.concat([df_y_test,df_y_pred],1)

# %%
plt.plot(y_test)
plt.plot(y_pred)
plt.xlabel("Caso")
plt.ylabel("Precio")
plt.legend(["Test","Predicciones"])

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 25.821651189939953
